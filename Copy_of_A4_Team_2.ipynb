# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import tensorflow as tf
# print(tf.__version__)
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import  metrics
from sklearn.model_selection import train_test_split
import IPython.display as ipd
import os
import math
# %matplotlib inline
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
% cd /content/drive/MyDrive/Colab\ Notebooks/music_data
% ls
# Out:
# /content/drive/.shortcut-targets-by-id/1R0W6BiPYvlf6nf4PFarJ57bi8p1jATAU/music_data
# features_30_sec.csv        features_only_10_genres.csv     genres_original/
# features_3_sec.csv         features_only_1.csv             genres_short/
# features_country_jazz.csv  features_only_country_jazz.csv  saved_models/

# %%
#!ls drive/MyDrive
#!ls drive/MyDrive/assignment\ data/arunima_fatema/our_data/

# %%
#Extract Audio features and save to a csv file
#TODO-- add more features here
import librosa
from librosa import feature
import numpy as np

fn_list_i = [
 feature.chroma_stft,
 feature.spectral_centroid,
 feature.spectral_bandwidth,
 feature.spectral_rolloff
]
 
fn_list_ii = [
 feature.rms,
 feature.zero_crossing_rate
]

# Additional Features
fn_list_iii = [
  feature.mfcc,
  feature.melspectrogram
]

def get_feature_vector(y,sr): 
   feat_vect_i = [ np.mean(funct(y,sr)) for funct in fn_list_i]
   feat_vect_ii = [ np.mean(funct(y)) for funct in fn_list_ii]

   mfccs_features = librosa.feature.mfcc(y = y, sr = sr, n_mfcc=40)
   #print(mfccs_features.shape)
   mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
   feat_vect_iii = []
   for i in range(0, len(mfccs_scaled_features)):
     feat_vect_iii.append(mfccs_scaled_features[i])
   feature_vector = feat_vect_i + feat_vect_ii + feat_vect_iii
   norm_feature_vector = [float(i)/max(feature_vector) for i in feature_vector]

   return feature_vector

# %%
genres = ['blues', 'classical', 'country', 'disco', 'hiphop','jazz', 'metal', 'pop', 'reggae', 'rock']
#genres = ['blues']
src_folder = '/content/drive/MyDrive/Colab Notebooks/music_data/genres_short/'
count = 1
extracted_features = []
for k in range(0, len(genres)):
  class_label = genres[k]
  path1 = src_folder + genres[k] + '_short'
  # print(path1)
  for i, (dirpath, dirnames, filenames) in enumerate(os.walk(path1)):
    # process files for specific genre
    for file in filenames:
      # print(file)
      # data = feature_extractor(path1+'/'+file)
      filename = path1+'/'+file
      #get duration in seconds
      audio, sample_rate = librosa.load(filename, sr = None)
      total_sec = math.ceil(librosa.get_duration(y=audio, sr=sample_rate))
      if(total_sec<10):
        continue
      #skip the file if it's shorter than 10 seconds
      feature_vector = get_feature_vector(audio, sample_rate)
      feature_vector.append(class_label)
      extracted_features.append(feature_vector)
      count+=1
    print('# of files processed:',count)
# Out:
# # of files processed: 301
# # of files processed: 601
# # of files processed: 901
# # of files processed: 1201
# # of files processed: 1501
# # of files processed: 1798
# # of files processed: 2098
# # of files processed: 2398
# # of files processed: 2698
# # of files processed: 2998

# %%
#saving into the csv file
import csv
norm_output = 'features_only_10_genres_with_mfcc.csv'
header =[
 'chroma_stft',
 'spectral_centroid',
 'spectral_bandwidth',
 'spectral_rolloff',
 'rmse',
 'zero_crossing_rate'
]

col_names = []
for k in range(0, 40):
  col_names.append('mfcc_'+str(k))

col_names.append('label')

header = header + col_names


with open(norm_output,'+w') as f:
 csv_writer = csv.writer(f, delimiter = ',')
 csv_writer.writerow(header)
 csv_writer.writerows(extracted_features)

# %% [markdown]
# # ACCESS CSV

# %%
norm_output = 'features_only_10_genres_with_mfcc.csv'
new_dataset = pd.read_csv(norm_output)

# %%
#pd.set_option('display.max_rows', 20)
new_dataset.head(5)
# Out:
#    chroma_stft  spectral_centroid  ...   mfcc_39  label
# 0     0.369745        1362.167172  ...  0.637063  blues
# 1     0.379309        1340.996909  ...  1.493249  blues
# 2     0.354039        1357.278823  ...  0.306750  blues
# 3     0.309263        1404.295102  ...  1.423163  blues
# 4     0.310806        1255.056763  ... -0.791258  blues
#
# [5 rows x 47 columns]

# %%
#check out the labels/genres
new_dataset['label'].value_counts()
# Out:
# disco        300
# hiphop       300
# blues        300
# metal        300
# reggae       300
# classical    300
# country      300
# rock         300
# pop          300
# jazz         297
# Name: label, dtype: int64

# %%
# changing Genres labels from text to numbers
from sklearn.preprocessing import LabelEncoder as LE 

Genres_label = new_dataset.iloc[:,-1]
genres_to_labels = LE()
new_target = genres_to_labels.fit_transform(Genres_label)

# %%
# Normalizing

from sklearn.preprocessing import StandardScaler
fit = StandardScaler()
input = fit.fit_transform(np.array(new_dataset.iloc[:,:-1], dtype = float))

# %%
# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(input, new_target, test_size = 0.2, random_state = 0)

# %%
X_train.shape
# Out:
# (2397, 46)

# %%
len(X_test)
# Out:
# 600

# %%
def trainModel(model,epochs,optimizer):
  batch_size=128
  model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics='accuracy')
  return model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=epochs,batch_size=batch_size)

# %%
model=keras.models.Sequential([
                         keras.layers.Dense(100,activation='relu',input_shape=(X_train.shape[1],)),
                         keras.layers.Dropout(0.2),
                         keras.layers.Dense(200,activation='relu'),
                         keras.layers.Dropout(0.2),
                         keras.layers.Dense(128,activation='relu'),
                         keras.layers.Dropout(0.2),
                         keras.layers.Dense(64,activation='relu'),
                         keras.layers.Dropout(0.2),
                         keras.layers.Dense(10,activation='softmax')
])
print(model.summary())
model_history=trainModel(model=model,epochs=100,optimizer='adam')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 100)               4700
#
#  dropout_12 (Dropout)        (None, 100)               0
#
#  dense_16 (Dense)            (None, 200)               20200
#
#  dropout_13 (Dropout)        (None, 200)               0
#
#  dense_17 (Dense)            (None, 128)               25728
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 59,534
# Trainable params: 59,534
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 19/19 [==============================] - 1s 17ms/step - loss: 2.1272 - accuracy: 0.2470 - val_loss: 1.8129 - val_accuracy: 0.3517
# Epoch 2/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.8063 - accuracy: 0.3421 - val_loss: 1.6067 - val_accuracy: 0.4117
# Epoch 3/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.6145 - accuracy: 0.4009 - val_loss: 1.4509 - val_accuracy: 0.4683
# Epoch 4/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.5141 - accuracy: 0.4560 - val_loss: 1.3247 - val_accuracy: 0.5300
# Epoch 5/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.3921 - accuracy: 0.4969 - val_loss: 1.2505 - val_accuracy: 0.5450
# Epoch 6/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.3155 - accuracy: 0.5215 - val_loss: 1.1918 - val_accuracy: 0.5467
# Epoch 7/100
# 19/19 [==============================] - 0s 8ms/step - loss: 1.2571 - accuracy: 0.5524 - val_loss: 1.1398 - val_accuracy: 0.5800
# Epoch 8/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1936 - accuracy: 0.5836 - val_loss: 1.0933 - val_accuracy: 0.6083
# Epoch 9/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1275 - accuracy: 0.5966 - val_loss: 1.0727 - val_accuracy: 0.6167
# Epoch 10/100
# 19/19 [==============================] - 0s 7ms/step - loss: 1.0821 - accuracy: 0.6287 - val_loss: 1.0568 - val_accuracy: 0.6183
# Epoch 11/100
# 19/19 [==============================] - 0s 8ms/step - loss: 1.0174 - accuracy: 0.6425 - val_loss: 0.9593 - val_accuracy: 0.6683
# Epoch 12/100
# 19/19 [==============================] - 0s 8ms/step - loss: 1.0116 - accuracy: 0.6546 - val_loss: 0.9497 - val_accuracy: 0.6617
# Epoch 13/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.9572 - accuracy: 0.6675 - val_loss: 0.9226 - val_accuracy: 0.6733
# Epoch 14/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.9133 - accuracy: 0.6892 - val_loss: 0.8933 - val_accuracy: 0.6850
# Epoch 15/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.8890 - accuracy: 0.7076 - val_loss: 0.8617 - val_accuracy: 0.6967
# Epoch 16/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8376 - accuracy: 0.7096 - val_loss: 0.8452 - val_accuracy: 0.6933
# Epoch 17/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8243 - accuracy: 0.7176 - val_loss: 0.8217 - val_accuracy: 0.7083
# Epoch 18/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7972 - accuracy: 0.7188 - val_loss: 0.8059 - val_accuracy: 0.7100
# Epoch 19/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7679 - accuracy: 0.7376 - val_loss: 0.8104 - val_accuracy: 0.7133
# Epoch 20/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7878 - accuracy: 0.7363 - val_loss: 0.8275 - val_accuracy: 0.7017
# Epoch 21/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7469 - accuracy: 0.7447 - val_loss: 0.7779 - val_accuracy: 0.7283
# Epoch 22/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6974 - accuracy: 0.7726 - val_loss: 0.7550 - val_accuracy: 0.7400
# Epoch 23/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6919 - accuracy: 0.7630 - val_loss: 0.7902 - val_accuracy: 0.7267
# Epoch 24/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6522 - accuracy: 0.7714 - val_loss: 0.7593 - val_accuracy: 0.7383
# Epoch 25/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6710 - accuracy: 0.7655 - val_loss: 0.7208 - val_accuracy: 0.7367
# Epoch 26/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6299 - accuracy: 0.7843 - val_loss: 0.7462 - val_accuracy: 0.7417
# Epoch 27/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5898 - accuracy: 0.7947 - val_loss: 0.7241 - val_accuracy: 0.7533
# Epoch 28/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5953 - accuracy: 0.7964 - val_loss: 0.7300 - val_accuracy: 0.7500
# Epoch 29/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5854 - accuracy: 0.7972 - val_loss: 0.7306 - val_accuracy: 0.7533
# Epoch 30/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5657 - accuracy: 0.8169 - val_loss: 0.7043 - val_accuracy: 0.7633
# Epoch 31/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5445 - accuracy: 0.8189 - val_loss: 0.7197 - val_accuracy: 0.7600
# Epoch 32/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5310 - accuracy: 0.8131 - val_loss: 0.7001 - val_accuracy: 0.7500
# Epoch 33/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5302 - accuracy: 0.8114 - val_loss: 0.7247 - val_accuracy: 0.7617
# Epoch 34/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5029 - accuracy: 0.8352 - val_loss: 0.6793 - val_accuracy: 0.7767
# Epoch 35/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4779 - accuracy: 0.8356 - val_loss: 0.6848 - val_accuracy: 0.7683
# Epoch 36/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4765 - accuracy: 0.8348 - val_loss: 0.6920 - val_accuracy: 0.7683
# Epoch 37/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4706 - accuracy: 0.8452 - val_loss: 0.6432 - val_accuracy: 0.7900
# Epoch 38/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4650 - accuracy: 0.8381 - val_loss: 0.6510 - val_accuracy: 0.7733
# Epoch 39/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4428 - accuracy: 0.8465 - val_loss: 0.6569 - val_accuracy: 0.7767
# Epoch 40/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4362 - accuracy: 0.8448 - val_loss: 0.6533 - val_accuracy: 0.7833
# Epoch 41/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4459 - accuracy: 0.8494 - val_loss: 0.6287 - val_accuracy: 0.8000
# Epoch 42/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4092 - accuracy: 0.8598 - val_loss: 0.6320 - val_accuracy: 0.7833
# Epoch 43/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4222 - accuracy: 0.8577 - val_loss: 0.6321 - val_accuracy: 0.7983
# Epoch 44/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4064 - accuracy: 0.8652 - val_loss: 0.6465 - val_accuracy: 0.7867
# Epoch 45/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4095 - accuracy: 0.8544 - val_loss: 0.6219 - val_accuracy: 0.7950
# Epoch 46/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3979 - accuracy: 0.8615 - val_loss: 0.6558 - val_accuracy: 0.7833
# Epoch 47/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3776 - accuracy: 0.8732 - val_loss: 0.6462 - val_accuracy: 0.7917
# Epoch 48/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3697 - accuracy: 0.8736 - val_loss: 0.6522 - val_accuracy: 0.7967
# Epoch 49/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3593 - accuracy: 0.8740 - val_loss: 0.6188 - val_accuracy: 0.7967
# Epoch 50/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3664 - accuracy: 0.8753 - val_loss: 0.6331 - val_accuracy: 0.8000
# Epoch 51/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3259 - accuracy: 0.8953 - val_loss: 0.6082 - val_accuracy: 0.8050
# Epoch 52/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3394 - accuracy: 0.8857 - val_loss: 0.6457 - val_accuracy: 0.7850
# Epoch 53/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3726 - accuracy: 0.8803 - val_loss: 0.6014 - val_accuracy: 0.8033
# Epoch 54/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3286 - accuracy: 0.8928 - val_loss: 0.6016 - val_accuracy: 0.8183
# Epoch 55/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3231 - accuracy: 0.8961 - val_loss: 0.5992 - val_accuracy: 0.8100
# Epoch 56/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2915 - accuracy: 0.9003 - val_loss: 0.6002 - val_accuracy: 0.8100
# Epoch 57/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3032 - accuracy: 0.8903 - val_loss: 0.6090 - val_accuracy: 0.8117
# Epoch 58/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3150 - accuracy: 0.8919 - val_loss: 0.5876 - val_accuracy: 0.8217
# Epoch 59/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2849 - accuracy: 0.9091 - val_loss: 0.6080 - val_accuracy: 0.8150
# Epoch 60/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2867 - accuracy: 0.9011 - val_loss: 0.6243 - val_accuracy: 0.8117
# Epoch 61/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2712 - accuracy: 0.9111 - val_loss: 0.5859 - val_accuracy: 0.8267
# Epoch 62/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2897 - accuracy: 0.9074 - val_loss: 0.5781 - val_accuracy: 0.8283
# Epoch 63/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2754 - accuracy: 0.9103 - val_loss: 0.5811 - val_accuracy: 0.8217
# Epoch 64/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2450 - accuracy: 0.9153 - val_loss: 0.5670 - val_accuracy: 0.8283
# Epoch 65/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2534 - accuracy: 0.9157 - val_loss: 0.5923 - val_accuracy: 0.8283
# Epoch 66/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2479 - accuracy: 0.9141 - val_loss: 0.5646 - val_accuracy: 0.8317
# Epoch 67/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2491 - accuracy: 0.9074 - val_loss: 0.5991 - val_accuracy: 0.8200
# Epoch 68/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2409 - accuracy: 0.9149 - val_loss: 0.5625 - val_accuracy: 0.8267
# Epoch 69/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2492 - accuracy: 0.9174 - val_loss: 0.6162 - val_accuracy: 0.8100
# Epoch 70/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2585 - accuracy: 0.9082 - val_loss: 0.5678 - val_accuracy: 0.8317
# Epoch 71/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2347 - accuracy: 0.9212 - val_loss: 0.5486 - val_accuracy: 0.8367
# Epoch 72/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2262 - accuracy: 0.9249 - val_loss: 0.5645 - val_accuracy: 0.8300
# Epoch 73/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2295 - accuracy: 0.9237 - val_loss: 0.5806 - val_accuracy: 0.8267
# Epoch 74/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2221 - accuracy: 0.9212 - val_loss: 0.5615 - val_accuracy: 0.8350
# Epoch 75/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2176 - accuracy: 0.9278 - val_loss: 0.5480 - val_accuracy: 0.8417
# Epoch 76/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2041 - accuracy: 0.9353 - val_loss: 0.6005 - val_accuracy: 0.8300
# Epoch 77/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2163 - accuracy: 0.9257 - val_loss: 0.5924 - val_accuracy: 0.8200
# Epoch 78/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2091 - accuracy: 0.9332 - val_loss: 0.5725 - val_accuracy: 0.8317
# Epoch 79/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2185 - accuracy: 0.9270 - val_loss: 0.5783 - val_accuracy: 0.8400
# Epoch 80/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2162 - accuracy: 0.9328 - val_loss: 0.5935 - val_accuracy: 0.8450
# Epoch 81/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2077 - accuracy: 0.9337 - val_loss: 0.5883 - val_accuracy: 0.8267
# Epoch 82/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2018 - accuracy: 0.9324 - val_loss: 0.5778 - val_accuracy: 0.8250
# Epoch 83/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1914 - accuracy: 0.9358 - val_loss: 0.5869 - val_accuracy: 0.8400
# Epoch 84/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2002 - accuracy: 0.9320 - val_loss: 0.5661 - val_accuracy: 0.8483
# Epoch 85/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1962 - accuracy: 0.9395 - val_loss: 0.5835 - val_accuracy: 0.8300
# Epoch 86/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1956 - accuracy: 0.9391 - val_loss: 0.5785 - val_accuracy: 0.8383
# Epoch 87/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1731 - accuracy: 0.9395 - val_loss: 0.5680 - val_accuracy: 0.8350
# Epoch 88/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1906 - accuracy: 0.9362 - val_loss: 0.5837 - val_accuracy: 0.8400
# Epoch 89/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1868 - accuracy: 0.9349 - val_loss: 0.6000 - val_accuracy: 0.8400
# Epoch 90/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1924 - accuracy: 0.9316 - val_loss: 0.5687 - val_accuracy: 0.8400
# Epoch 91/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1860 - accuracy: 0.9387 - val_loss: 0.6252 - val_accuracy: 0.8383
# Epoch 92/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1733 - accuracy: 0.9420 - val_loss: 0.5859 - val_accuracy: 0.8283
# Epoch 93/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1804 - accuracy: 0.9395 - val_loss: 0.6406 - val_accuracy: 0.8183
# Epoch 94/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1857 - accuracy: 0.9366 - val_loss: 0.6107 - val_accuracy: 0.8317
# Epoch 95/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1876 - accuracy: 0.9387 - val_loss: 0.6238 - val_accuracy: 0.8333
# Epoch 96/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1743 - accuracy: 0.9433 - val_loss: 0.6020 - val_accuracy: 0.8367
# Epoch 97/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1804 - accuracy: 0.9391 - val_loss: 0.5749 - val_accuracy: 0.8383
# Epoch 98/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1707 - accuracy: 0.9504 - val_loss: 0.5695 - val_accuracy: 0.8383
# Epoch 99/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1633 - accuracy: 0.9504 - val_loss: 0.5693 - val_accuracy: 0.8300
# Epoch 100/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1643 - accuracy: 0.9424 - val_loss: 0.5690 - val_accuracy: 0.8283

# %%
#Plot the Accuray curves
import matplotlib.pyplot as plt
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Accuracy Graph')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend(['Training Data','Test Data'],loc='lower right')
plt.show()

# %%
#Plot the loss curves
import matplotlib.pyplot as plt
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Loss Graph')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['Training Data','Test Data'],loc='upper right')
plt.show()

# %% [markdown]
# # End

# %%
# to show the plot of each audio file
def show_plot(filename):
  plt.figure(figsize=(14, 5))
  data, sample_rate = librosa.load(filename)
  print(data.shape)
  print(sr)
  librosa.display.waveplot(data, sr=sample_rate)

# %%
### This is a simple test to load an audio file and play it

fname = '/content/drive/MyDrive/Colab Notebooks/music_data/genres_short/jazz_short/10_jazz.00099.wav'

plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(fname)
print(data.shape)
print(sample_rate)
librosa.display.waveplot(data, sr=sample_rate)
ipd.Audio(fname)
# Out:
# (220500,)
# 22050
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
### model

num_labels = len(genres)

# first layer
model = Sequential()
model.add(Dense(100, input_shape = (X_train.shape[1],)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
# compile model

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='Adam')

# %%
## Trianing the model

from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

# #checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
#                                verbose=1, save_best_only=True)
# #start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), verbose=1)


#duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-5ebcee092108> in <module>()
#      11 # #start = datetime.now()
#      12
# ---> 13 model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), verbose=1)
#      14
#      15
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 810, in train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 1665, in categorical_crossentropy
#         y_true, y_pred, from_logits=from_logits, axis=axis)
#     File "/usr/local/lib/python3.7/dist-packages/keras/backend.py", line 4994, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 2) are incompatible

# %% [markdown]
# #  Other codes

# %%
src_folder = '/content/drive/MyDrive/Colab Notebooks/music_data/genres_short'
for i, (dirpath, dirnames, filenames) in enumerate(os.walk(src_folder)):
  # process files for specific genre
  for file in filenames:
    if(file==str("jazz.00054.wav")):
      # As librosa only read files <1Mb
      continue
      split_wav = SplitWavAudioMubin(src_folder, dest_folder, file)
      split_wav.multiple_split(sec_per_split=10)
      count+=1
  print('# of files processed:',count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-043dd7fd4d27> in <module>()
#       1 src_folder = '/content/drive/MyDrive/Colab Notebooks/music_data/genres_short'
# ----> 2 for i, (dirpath, dirnames, filenames) in enumerate(os.walk(src_folder)):
#       3   # process files for specific genre
#       4   for file in filenames:
#       5     if(file==str("jazz.00054.wav")):
#
# NameError: name 'os' is not defined

# %%
#### extracting features from an audio file
def feature_extractor(filename):
  #print(filename)
  audio, sample_rate = librosa.load(filename, res_type='kaiser_fast')
  mfccs_features = librosa.feature.mfcc(y = audio, sr = sample_rate, n_mfcc=40)
  #print(mfccs_features.shape)
  mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)

  return mfccs_scaled_features

# %%
#### Load all music files and extract features

path1 = 'drive/MyDrive/assignment data/arunima_fatema/our_data/genres_original/'
genres = ['blues', 'classical', 'country', 'disco', 'hiphop','jazz', 'metal', 'pop', 'reggae', 'rock']

# 'blues', 'classical', 'country', 'disco', 'hiphop','jazz', 'metal', 'pop', 'reggae', 'rock'
extracted_features = []
n_files = 100

for i in range(0, len(genres)):
  class_label = genres[i] 
  #print(genres[i])
  for j in range(0, n_files):
    if (j < 10):
      st = genres[i] + '.' + '0000' + str(j) + '.wav'
    else:
      st = genres[i] + '.' + '000' + str(j) + '.wav'
    filename = path1 + genres[i] + '/'+ st
    # print(filename)
    if(j == 54):
      continue
    data = feature_extractor(filename)
    #play_audio(filename)
    #show_plot(filename)
    extracted_features.append([data, class_label])

# %%
# converting extracted feature to Pandas dataframe
extracted_features_df = pd.DataFrame(extracted_features, columns=['feature', 'music_genre'])
extracted_features_df.head()

# %%
# split the dataset into feature and music genre class
X = np.array(extracted_features_df['feature'].tolist())
y = np.array(extracted_features_df['music_genre'].tolist())

# %%
X.shape

# %%
## Label Encoding
y = np.array(pd.get_dummies(y))

# %%
# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.shape

# %%
X_test.shape
X_test

# %% [markdown]
# # Model Creation

# %%
num_labels = y.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac4460899757> in <module>()
# ----> 1 num_labels = y.shape[1]
#
# NameError: name 'y' is not defined

# %%
### model

# first layer
model = Sequential()
model.add(Dense(100, input_shape = (40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()

# %%
# compile model

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='Adam')

# %%
## Trianing the model

from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
